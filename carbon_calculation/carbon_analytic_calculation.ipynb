# %% [markdown]
# # YvesBlue Backend Challenge
# ## Carbon Analytic Calculation
# ### Goal: Utilizing this Jupyter Notebook (and additional libraries/files/tools as needed) implement a function that can be utilized to calculate the (strawman) Adjusted CO2 Total emissions for a company.
# ### Notes: The calculation is laid out in this [image](calculation.png?raw=true). The data is stored inside of the [included data file](data.json?raw=true). Your code structure can take whatever you believe to be best (individual function, class, module, etc.). Please implement the code as well as write tests for the calculation, showcasing how you would write tests for such requirements. Provide instructions with your submission for how to call your implemented function as well as how to run the tests.
# ## Author: @github_username (Full Name)
# ## Date: YYYY-MM-DD

# %%
## Import Libraries

import decimal
import json
import os

import numpy

# %%
## Specify Calculation Function

class CarbonAnalytic:
    # def __init__(self):
    def __init__(self, mu_purch=0.5, mu_purch_max=0.8, phi_prod=0.05, print_errors=False):
        self.__keys = {
            "CO2_tot": "Total CO2 Equivalents Emissions",
            "CC": "Carbon Credit Value",
            "RE_purch": "Renewable Energy Purchased",
            "RE_prod": "Renewable Energy Produced",
            "E_tot": "Total Energy Use",
        }

        self.__mu_purch = mu_purch
        self.__mu_purch_max = mu_purch_max
        self.__phi_prod = phi_prod
        self.__print_errors = print_errors

    def calculation_from_file(self, file_path='data.json'):
        ''' To be implemented what should happen if:
            - file is missing
            - cannot open file
            - cannot read from file
            - invalid file format (invalid json)
        '''
        return self.calculation_from_list(json.loads(open(file_path, 'r').read()))
        
    def calculation_from_list(self, data_list):
        for data in data_list:
            data["Adjusted CO2 Total Emissions"] = float(self.calculation_from_data(data))
        return data_list

    def calculation_from_data(self, data):
        try:
            self.is_valid(data)
        except Exception as e:
            if self.__print_errors:
                print(str(e)) # error message
            return None
        
        return (
            decimal.Decimal(data[self.__keys['CO2_tot']]) - decimal.Decimal(data[self.__keys['CC']])
        ) * (
            decimal.Decimal(1) - decimal.Decimal(min(
                decimal.Decimal(self.__mu_purch) * (
                    decimal.Decimal(data[self.__keys['RE_purch']])
                    /
                    decimal.Decimal(data[self.__keys['E_tot']])
                ),
                decimal.Decimal(self.__mu_purch_max)
            ))
        ) - decimal.Decimal(self.__phi_prod) * decimal.Decimal(data[self.__keys['RE_prod']])

    def is_valid(self, data):
        errors = []
        for _k, key in self.__keys.items():
            if key not in data.keys():
                errors.append('Key "{}" is missing from data: {}.'.format(key, data))
                continue
            if type(data[key]) not in (int, float):
                errors.append('Key "{}" has unexpected format: {}.'.format(key, data[key]))
                # continue
        if self.__keys['CO2_tot'] in data.keys() and data[self.__keys['CO2_tot']] == 0:
            errors.append('Key "{}" found with invalid value of {} from data: {}'.format(
                self.__keys['CO2_tot'], data[self.__keys['CO2_tot']], data
            ))
        if len(errors) > 0:
            raise Exception('\n'.join(errors))
        return True

# %%
## Demonstrate Solution with Calculation Function

print(json.dumps(CarbonAnalytic(print_errors=True).calculation_from_file(), indent=4)) # pretty print
# Out:
# [
#     {
#         "ISIN": "US0000000000",
#         "Total Energy Use": 7000000,
#         "Total CO2 Equivalents Emissions": 94972.49198,
#         "Renewable Energy Purchased": 10576.00479,
#         "Renewable Energy Produced": 96652.16115,
#         "Carbon Credit Value": 8171.323352,
#         "Adjusted CO2 Total Emissions": 81902.98845798662
#     },
#     {
#         "ISIN": "US0000000001",
#         "Total Energy Use": 80000000,
#         "Total CO2 Equivalents Emissions": 306900.6192,
#         "Renewable Energy Purchased": 31961.79405,
#         "Renewable Energy Produced": 38372.1921,
#         "Carbon Credit Value": 57387.1,
#         "Adjusted CO2 Total Emissions": 247545.0664717915
#     },
#     {
#         "ISIN": "US0000000002",
#         "Total Energy Use": 153000000,
#         "Total CO2 Equivalents Emissions": 171320.1651,
#         "Renewable Energy Purchased": 62884.91047,
#         "Renewable Energy Produced": 10689.83474,
#         "Carbon Credit Value": 84303.7259,
#         "Adjusted CO2 Total Emissions": 86464.06504146893
#     },
#     {
#         "ISIN": "US0000000003",
#         "Total Energy Use": 226000000,
#         "Total CO2 Equivalents Emissions": 2250.272892,
#         "Renewable Energy Purchased": 12949.74785,
#         "Renewable Energy Produced": 27468.66907,
#         "Carbon Credit Value": 45713.96386,
#         "Adjusted CO2 Total Emissions": -44835.87919176844
#     },
#     {
#         "ISIN": "US0000000004",
#         "Total Energy Use": 299000000,
#         "Total CO2 Equivalents Emissions": 132696.7376,
#         "Renewable Energy Purchased": 42559.65263,
#         "Renewable Energy Produced": 69567.95366,
#         "Carbon Credit Value": 17515.5,
#         "Adjusted CO2 Total Emissions": 111694.64246973954
#     },
#     {
#         "ISIN": "US0000000005",
#         "Total Energy Use": 372000000,
#         "Total CO2 Equivalents Emissions": 204269.3867,
#         "Renewable Energy Purchased": 9991.766644,
#         "Renewable Energy Produced": 55829.34503,
#         "Carbon Credit Value": 26647.856,
#         "Adjusted CO2 Total Emissions": 174827.6780279547
#     },
#     {
#         "ISIN": "US0000000006",
#         "Total Energy Use": 445000000,
#         "Total CO2 Equivalents Emissions": 64963.62994,
#         "Renewable Energy Purchased": 9515.906056,
#         "Renewable Energy Produced": 24720.73308,
#         "Carbon Credit Value": 10556.11359,
#         "CO2 Analytic": 53170.89797,
#         "Adjusted CO2 Total Emissions": 53170.89796924233
#     },
#     {
#         "ISIN": "US0000000007",
#         "Total Energy Use": 518000000,
#         "Total CO2 Equivalents Emissions": 89288.41927,
#         "Renewable Energy Purchased": 32904.92748,
#         "Renewable Energy Produced": 4051.865565,
#         "Carbon Credit Value": 8902.593156,
#         "CO2 Analytic": 80180.67966,
#         "Adjusted CO2 Total Emissions": 80180.67966028793
#     },
#     {
#         "ISIN": "US0000000008",
#         "Total Energy Use": 591000000,
#         "Total CO2 Equivalents Emissions": 59887.44837,
#         "Renewable Energy Purchased": 4408.314004,
#         "Renewable Energy Produced": 31232.14481,
#         "Carbon Credit Value": 8838.602818,
#         "Adjusted CO2 Total Emissions": 49487.04792288686
#     },
#     {
#         "ISIN": "US0000000009",
#         "Total Energy Use": 664000000,
#         "Total CO2 Equivalents Emissions": 270793.8773,
#         "Renewable Energy Purchased": 6147.617183,
#         "Renewable Energy Produced": 9418.298827,
#         "Carbon Credit Value": 2135.478871,
#         "Adjusted CO2 Total Emissions": 268186.23980618425
#     },
#     {
#         "ISIN": "US0000000010",
#         "Total Energy Use": 737000000,
#         "Total CO2 Equivalents Emissions": 436123.8946,
#         "Renewable Energy Purchased": 61287.84832,
#         "Renewable Energy Produced": 9800.114222,
#         "Carbon Credit Value": 45901.30643,
#         "Adjusted CO2 Total Emissions": 389716.35728739743
#     },
#     {
#         "ISIN": "US0000000011",
#         "Total Energy Use": 810000000,
#         "Total CO2 Equivalents Emissions": 219384.6241,
#         "Renewable Energy Purchased": 18766.81362,
#         "Renewable Energy Produced": 13746.23147,
#         "Carbon Credit Value": 47047.32813,
#         "CO2 Analytic": 171647.988,
#         "Adjusted CO2 Total Emissions": 171647.9879632202
#     },
#     {
#         "ISIN": "US0000000012",
#         "Total Energy Use": 883000000,
#         "Total CO2 Equivalents Emissions": 907965.0176,
#         "Renewable Energy Purchased": 11742.15742,
#         "Renewable Energy Produced": 15078.18917,
#         "Carbon Credit Value": 3432.989027,
#         "Adjusted CO2 Total Emissions": 903772.1048690465
#     },
#     {
#         "ISIN": "US0000000013",
#         "Total Energy Use": 956000000,
#         "Total CO2 Equivalents Emissions": 63194.4312,
#         "Renewable Energy Purchased": 76353.30911,
#         "Renewable Energy Produced": 49.54423131,
#         "Carbon Credit Value": 6784.725662,
#         "Adjusted CO2 Total Emissions": 56404.97567597229
#     },
#     {
#         "ISIN": "US0000000014",
#         "Total Energy Use": 1029000000,
#         "Total CO2 Equivalents Emissions": 58244.40199,
#         "Renewable Energy Purchased": 898.2632691,
#         "Renewable Energy Produced": 903570.7574,
#         "Carbon Credit Value": 2965.056586,
#         "Adjusted CO2 Total Emissions": 10100.783406008977
#     },
#     {
#         "ISIN": "US0000000015",
#         "Total Energy Use": 1102000000,
#         "Total CO2 Equivalents Emissions": 9657.810784,
#         "Renewable Energy Purchased": 9985.097548,
#         "Renewable Energy Produced": 14877.02366,
#         "Carbon Credit Value": 83257.80621,
#         "Adjusted CO2 Total Emissions": -74343.51316837665
#     },
#     {
#         "ISIN": "US0000000016",
#         "Total Energy Use": 1175000000,
#         "Total CO2 Equivalents Emissions": 8939.83813,
#         "Renewable Energy Purchased": 10044.20882,
#         "Renewable Energy Produced": 3664.637195,
#         "Carbon Credit Value": 7357.74964,
#         "Adjusted CO2 Total Emissions": 1398.8498681958872
#     },
#     {
#         "ISIN": "US0000000017",
#         "Total Energy Use": 1248000000,
#         "Total CO2 Equivalents Emissions": 294541.4886,
#         "Renewable Energy Purchased": 29398.99459,
#         "Renewable Energy Produced": 28384.09547,
#         "Carbon Credit Value": 31341.08653,
#         "Adjusted CO2 Total Emissions": 261778.09720547573
#     },
#     {
#         "ISIN": "US0000000018",
#         "Total Energy Use": 1321000000,
#         "Total CO2 Equivalents Emissions": 617044.557,
#         "Renewable Energy Purchased": 15389.82384,
#         "Renewable Energy Produced": 6266.641717,
#         "Carbon Credit Value": 8289.310471,
#         "Adjusted CO2 Total Emissions": 608438.3684037838
#     },
#     {
#         "ISIN": "US0000000019",
#         "Total Energy Use": 1394000000,
#         "Total CO2 Equivalents Emissions": 683013.3757,
#         "Renewable Energy Purchased": 25050.59721,
#         "Renewable Energy Produced": 3177.824916,
#         "Carbon Credit Value": 9323.29235,
#         "Adjusted CO2 Total Emissions": 673525.1388979867
#     }
# ]

# %%
## Test Calculation Function

class CarbonAnalyticTest:
    def test_div_by_zero(self):
        assert None == CarbonAnalytic().calculation_from_data(
            {
                "ISIN": "US0000000000",
                "Total Energy Use": 7000000,
                "Total CO2 Equivalents Emissions": 0,
                "Renewable Energy Purchased": 10576.00479,
                "Renewable Energy Produced": 96652.16115,
                "Carbon Credit Value": 8171.323352,
                "Adjusted CO2 Total Emissions": 81902.98845798662
            },
        )
        print('OK - test_div_by_zero')

    def test_with_known_value(self):
        err = decimal.Decimal(10**(-5))
        res = decimal.Decimal(81902.98845798662)
        tst = decimal.Decimal(
            CarbonAnalytic().calculation_from_data(
                {
                    "ISIN": "US0000000000",
                    "Total Energy Use": 7000000,
                    "Total CO2 Equivalents Emissions": 94972.49198,
                    "Renewable Energy Purchased": 10576.00479,
                    "Renewable Energy Produced": 96652.16115,
                    "Carbon Credit Value": 8171.323352,
                },
            )
        )
        assert err > abs(res - tst)
        print('OK - test_with_known_value')

    def test_all(self):
        self.test_div_by_zero()
        self.test_with_known_value()
        # test_from_file()
        # test_with_lists()
        # test_is_valid()
        # test_corner_cases() # if applicable
        # test_precision() # if applicable

CarbonAnalyticTest().test_all()
# Out:
# OK - test_div_by_zero
# OK - test_with_known_value

# %% [markdown]
# # Run code:
# ### Using data (with python-dictionary):
# ```python
# CarbonAnalytic(print_errors=True).calculation_from_data({
#     "ISIN": "US0000000000",
#     "Total Energy Use": 7000000,
#     "Total CO2 Equivalents Emissions": 94972.49198,
#     "Renewable Energy Purchased": 10576.00479,
#     "Renewable Energy Produced": 96652.16115,
#     "Carbon Credit Value": 8171.323352,
# })
# ```
# ### Using list (with python-list-of-dictionaries):
# ```python
# CarbonAnalytic(print_errors=True).calculation_from_list([
#     {
#         "ISIN": "US0000000000",
#         "Total Energy Use": 7000000,
#         "Total CO2 Equivalents Emissions": 94972.49198,
#         "Renewable Energy Purchased": 10576.00479,
#         "Renewable Energy Produced": 96652.16115,
#         "Carbon Credit Value": 8171.323352,
#         "Adjusted CO2 Total Emissions": 81902.98845798662
#     },
#     {
#         "ISIN": "US0000000001",
#         "Total Energy Use": 80000000,
#         "Total CO2 Equivalents Emissions": 306900.6192,
#         "Renewable Energy Purchased": 31961.79405,
#         "Renewable Energy Produced": 38372.1921,
#         "Carbon Credit Value": 57387.1,
#         "Adjusted CO2 Total Emissions": 247545.0664717915
#     },
# ])
# ```
# ### Using file (containing json-list-of-dictionaries):
# ```python
# CarbonAnalytic(print_errors=True).calculation_from_file('data.json')
# ```
#
# # Run tests:
# ```python
# CarbonAnalyticTest().test_all()
# ```
